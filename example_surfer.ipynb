# %% [markdown]
# # DuckDuckGo

# %%
from llm_surfer import LLMSurfer

# %%
query = """
flood inurl:gov
""".strip()

max_results = 5

research_goal = """
The goal of this research is to develop a comprehensive inventory of federal climate adaptation policies in the United States. We define climate adaptation policies as policies that support “adjustments in ecological, social, or economic systems in response to actual or expected climatic stimuli and their effects or impacts.”
 
### Grounds for inclusion:
* Action constitutes a policy instrument (can include plans or strategies). Policy instruments, or tools, are “the techniques through which governments generate, evaluate, and implement policy options” (Kapano and Howlett, 2020)
* Action constitutes adaptation based on the three categories listed below
* We include policies that would not be implemented for any other reason than to adapt to climate change (we call these policies “Explicit Adaptation Policies”). An example of an Explicit Adaptation policy is a National Adaptation Strategy designed to respond to climate change.
* We also include policies that would not be implemented for any other reason other than to address climate-related hazards (such as flood, heat, or drought), but do not directly mention climate change or adaptation (we call these “Explicit Hazard Policies”). For example, though a policy on decreasing flood risk may not mention climate change, it still increases resilience to a climate hazard (flooding) so would be included.
* We also include policies that may be implemented for multiple reasons not exclusive to climate adaptation, but that have an impact on climate resilience (we call these “Implicit Policies”). An example of this is a social services policy like funding affordable housing after a disaster.
 
### Grounds for exclusion:
* Policies focused exclusively on climate change mitigation 
* Aspirational policy statements with no clear policy instrument
* Non-adaptation risk reduction:
    - Environmental or disaster preparedness policies that did not significantly relate to the effects of climate change were excluded. This includes environmental management of toxics and earthquake policies for example. 
    - Actions taking place solely at the local or state government level, with no federal involvement

### Hazard Classification:
After you have decided the relevancy of each document, classify it according to the following hazard types:
* Explicit Adaptation: Policies with a primary stated goal to adapt to climate change.
* Explicit Hazard: Policies that address climate-related hazards (such as flood, heat, or drought), but do not directly mention climate change or adaptation.
* Implicit: Policies that do not have a stated goal to address climate-related hazards or adaptation, but that have an impact on climate resilience.
Even if you have decided this document is not relevant, please supply a classification.

### Sector Classification:
After you have decided the hazard class of each document, classify it according to the following sector types:
* Emergency management: Includes public safety during extreme events and responses to natural hazards. 
* Infrastructure: Built environment, including land use planning, housing, utilities, and public works. Excludes coastal infrastructure and transportation. 
* Health: Includes public health agencies, clinical services, and medical interventions. 
* Education: Includes primary, secondary, and tertiary school systems. 
* Human services: Includes gender equality, immigration, families, Indigenous groups, social affairs, minority affairs, religious affairs, welfare and social services. 
* Agriculture: Includes irrigation, plant/seed technology. 
* Water: Water for human consumption and recreation, as well as irrigation for crops. 
* Environment: Includes natural resources, public park systems, sustainability, mines, meteorology, geosciences, biodiversity, and conservation. 
* Energy: Includes oil, natural gas, hydropower, and electrical grids. 
* Coast management: Coastal settlements infrastructure. 
* Development: Includes international cooperation, development aid, sustainable development, and rural development. - local development included.
* National Security: Military response to instability/volatility associated with climate change. May include responses to population displacement, disease transmission, Arctic sovereignty, or resource conflict. 
* Forestry: Forest ecosystem health; forest ecosystems used in economic activities. Includes game management and community forests. 
* Fisheries: Marine/riparian ecosystem health; marine/riparian ecosystems used in economic activities. 
* Transportation: Includes road/highway maintenance, public transportation, air traffic, railroad systems, shipping. Insurance Private sector. 
* Tourism: Private sector. Includes recreation. 
* Economy: Costs associated with climate change. Includes finance, employment, labour, trade, treasury, industry, and livelihoods. 
* Culture: Impacts of climate change on particular sites or practices considered important to group identity and/or survival. 
* Technology: Includes science, research, and innovation. 
* Inter-sectoral: Multiple sections. 
* Other
Even if you have decided this document is not relevant, please supply a classification.

### Policy Instrument Classification:
After you have decided the sector class of each document, classify it according to the following policy instruments.
* Regulation: Laws defining responsibilities, conferring decision-making authority, defining liabilities, enabling other instruments.
* Inter-governmental mandate: Directives requiring adaptation by other levels of government.
* Spatial planning: Rules for allocating land uses, public space design standards (including tree planting).
* Infrastructure performance standards:  Standards for infrastructure performance, including performance assessment requirement (e.g. flood risk assessment).
* Building regulations: Rules for building and construction standards. 
* Strategic planning: Adoption of policy guidance documents that integrate adaptation considerations in impacted sectors (including sustainability planning). 
* Adaptation planning: Adoption of policy guidance documents for adaptation (including climate or resilience plans that cover adaptation).
* User charges: Fees paid on the basis of service usage.
* Grants or subsidies: Financial transfers awarded on a conditional basis.
* Loans: Financial transfers given on the basis of repayment.
* Direct expenditures: Capital investments (e.g. road works, parks, tree planting); land acquisition. 
* Demostration projects: Use of government- owned facilities to demonstrate new ideas or technologies.
* Operations: Procurement; (emergency) response procedures; procedures for updating policies and protocols; routine maintenance; best practices implementation.
* Facilities: Adapting city facilities to different purposes (e.g. cooling centers); upgrading city- owned properties.
Even if you have decided this document is not relevant, please supply a classification.
""".strip()

prompt = """
# Research task
You are a helpful AI assistant trained by Meta AI that is uniquely skilled at helping people with data collection and other associated research tasks.
You will be given the text from a webpage or PDF, its title, if one exists, and its url. From this information you must decide how relevant this webpage to the research goal.
The cateogries of relevancy should only be one of the following: 'Not relevant', 'Somewhat relevant', 'Relevant', 'Very relevant', 'Highly relevant'.
No matter the input, you should respond with two things 1) a determination of whether or not this input is relevant to the research goal and 2) a short comment on why you made that determination.

## Research Goal
{research_goal}

## Input website
### Title
{title}
### URL
{url}
### Text
{text}

## Correctly formatted relevancy determination
""".strip()

json_schema = {
    "type": "object",
    "properties": {
        "relevancy": {"type": "string"},
        "comment": {"type": "string"},
        "hazard_class": {"type":"string"},
        "sector_class": {"type":"string"},
        "policy_instrument":{"type":"string"}
    }
}

# %%
llm_surfer = LLMSurfer(
    llm_name = "/cluster/tufts/tuftsai/models/llama-3-70B-instruct", 
    research_goal = research_goal, 
    base_prompt = prompt, 
    query = query, 
    max_results = max_results, 
    json_schema = json_schema,
    search_engine='ddg'
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
rel_docs = llm_surfer(num_rel_chunks=5) # change to get more or less rel chunks in the output
rel_docs
# Out:
# Collecting links from ddg
# 100%|██████████| 5/5 [00:46<00:00,  9.33s/it]
# 5 links collected out of 5. The rest are unreachable
# ----------------------------------------------------------------------------------------------------
# Webpage #1
# Reading URL: https://www.floodsmart.gov/
# Result 1: Relevant, | The National Flood Insurance Program because: This webpage is relevant to the research goal because it provides information on the National Flood Insurance Program, which is a federal policy instrument that supports adaptation to flooding, a climate-related hazard. The program provides flood insurance and encourages mitigation strategies to reduce flood risks, which aligns with the research goal of developing a comprehensive inventory of federal climate adaptation policies in the United States.
# ----------------------------------------------------------------------------------------------------
# Webpage #2
# Reading URL: https://www.fema.gov/flood-insurance
# Result 2: Very relevant, Flood Insurance | FEMA.gov because: This webpage is very relevant to the research goal as it discusses flood insurance policies and the National Flood Insurance Program (NFIP), which is a federal policy instrument that supports adaptation to climate-related hazards such as flooding.
# ----------------------------------------------------------------------------------------------------
# Webpage #3
# Reading URL: https://www.fema.gov/flood-maps
# Result 3: Very relevant, Flood Maps | FEMA.gov because: This webpage is very relevant to the research goal as it provides information on flood maps, which are a tool used by communities to know which areas have the highest risk of flooding. The webpage also discusses the process of updating flood maps and the role of FEMA in maintaining and updating the data. This information is directly related to the research goal of developing a comprehensive inventory of federal climate adaptation policies in the United States.
# ----------------------------------------------------------------------------------------------------
# Webpage #4
# Reading URL: https://msc.fema.gov/portal/home
# Result 4: Very relevant, FEMA Flood Map Service Center | Welcome! because: This webpage is directly related to flood hazard mapping and risk assessment, which falls under the category of Explicit Hazard policies. The webpage provides information on flood maps, hazard updates, and tools for better understanding flood risk, making it highly relevant to the research goal of developing a comprehensive inventory of federal climate adaptation policies in the United States.
# ----------------------------------------------------------------------------------------------------
# Webpage #5
# Reading URL: https://www.floodsmart.gov/get-flood-insurance
# Result 5: Relevant, | Protect the life you've built - FloodSmart because: This webpage is relevant to the research goal as it provides information on flood insurance, which is a policy instrument that supports adaptation to climate change. The webpage also mentions the impacts of floods and the importance of flood insurance in rebuilding lives, which aligns with the definition of climate adaptation policies.
# ----------------------------------------------------------------------------------------------------
#                                           title  \
# 0        | The National Flood Insurance Program
# 1                    Flood Insurance | FEMA.gov
# 2                         Flood Maps | FEMA.gov
# 3      FEMA Flood Map Service Center | Welcome!
# 4  | Protect the life you've built - FloodSmart
#
#                                               url      relevancy  \
# 0                     https://www.floodsmart.gov/       Relevant
# 1            https://www.fema.gov/flood-insurance  Very relevant
# 2                 https://www.fema.gov/flood-maps  Very relevant
# 3                https://msc.fema.gov/portal/home  Very relevant
# 4  https://www.floodsmart.gov/get-flood-insurance       Relevant
#
#                                          llm_comment     hazard_class  \
# 0  This webpage is relevant to the research goal ...  Explicit Hazard
# 1  This webpage is very relevant to the research ...  Explicit Hazard
# 2  This webpage is very relevant to the research ...  Explicit Hazard
# 3  This webpage is directly related to flood haza...  Explicit Hazard
# 4  This webpage is relevant to the research goal ...  Explicit Hazard
#
#            sector_class policy_instrument  \
# 0  Emergency management         Insurance
# 1  Emergency management         Insurance
# 2  Emergency management        Regulation
# 3  Emergency management  Spatial planning
# 4  Emergency management         Insurance
#
#                                Most Relevant Chunk 1  \
# 0         information only on official, secure we...
# 1   to the .gov website. Share sensitive informat...
# 2   to the .gov website. Share sensitive informat...
# 3   a range of other flood hazard\t\t\t\t\tproduc...
# 4   Why buy flood insurance? Hear from real life ...
#
#                                Most Relevant Chunk 2  \
# 0  An official website of the United States gover...
# 1   Insurance Program. See Rules & Legislation Fi...
# 2  ts the maps, you can submit data to amend or r...
# 3  \t\t\t\t\t\tVisit Search All\t\t\t\t\t\t\tProd...
# 4         information only on official, secure we...
#
#                                Most Relevant Chunk 3  \
# 0   your corner of the world from flood risks. Di...
# 1  gov/flood-insurance-provider or call the NFIP ...
# 2   Flood maps help mortgage lenders determine in...
# 3  \tHazard Mapping Updates Overview Fact Sheet \...
# 4   Secure .gov websites use HTTPS           A   ...
#
#                                Most Relevant Chunk 4  \
# 0   Secure .gov websites use HTTPS           A   ...
# 1   coverage against flood. NFIP Direct NFIP offe...
# 2   to make the maps as accurate as possible. Abo...
# 3                                                NaN
# 4  An official website of the United States gover...
#
#                                Most Relevant Chunk 5
# 0   coverage limits and what is or isn't covered....
# 1   Flood insurance is available to anyone living...
# 2   a flood map, you can see the relationship bet...
# 3                                                NaN
# 4   4% of homeowners have flood insurance. What's...

# %% [markdown]
# # Congress

# %%
from llm_surfer import LLMSurfer

# %%
query = """
"wildfire" OR "fire" OR "fire zone"
""".strip()

max_results = 5

research_goal = """
The goal of this research is to develop a comprehensive inventory of federal climate adaptation policies in the United States. We define climate adaptation policies as policies that support “adjustments in ecological, social, or economic systems in response to actual or expected climatic stimuli and their effects or impacts.”
 
### Grounds for inclusion:
* Action constitutes a policy instrument (can include plans or strategies). Policy instruments, or tools, are “the techniques through which governments generate, evaluate, and implement policy options” (Kapano and Howlett, 2020)
* Action constitutes adaptation based on the three categories listed below
* We include policies that would not be implemented for any other reason than to adapt to climate change (we call these policies “Explicit Adaptation Policies”). An example of an Explicit Adaptation policy is a National Adaptation Strategy designed to respond to climate change.
* We also include policies that would not be implemented for any other reason other than to address climate-related hazards (such as flood, heat, or drought), but do not directly mention climate change or adaptation (we call these “Explicit Hazard Policies”). For example, though a policy on decreasing flood risk may not mention climate change, it still increases resilience to a climate hazard (flooding) so would be included.
* We also include policies that may be implemented for multiple reasons not exclusive to climate adaptation, but that have an impact on climate resilience (we call these “Implicit Policies”). An example of this is a social services policy like funding affordable housing after a disaster.
 
### Grounds for exclusion:
* Policies focused exclusively on climate change mitigation 
* Aspirational policy statements with no clear policy instrument
* Non-adaptation risk reduction:
    - Environmental or disaster preparedness policies that did not significantly relate to the effects of climate change were excluded. This includes environmental management of toxics and earthquake policies for example. 
    - Actions taking place solely at the local or state government level, with no federal involvement

### Hazard Classification:
After you have decided the relevancy of each document, classify it according to the following hazard types:
* Explicit Adaptation: Policies with a primary stated goal to adapt to climate change.
* Explicit Hazard: Policies that address climate-related hazards (such as flood, heat, or drought), but do not directly mention climate change or adaptation.
* Implicit: Policies that do not have a stated goal to address climate-related hazards or adaptation, but that have an impact on climate resilience.
Even if you have decided this document is not relevant, please supply a classification.

### Sector Classification:
After you have decided the hazard class of each document, classify it according to the following sector types:
* Emergency management: Includes public safety during extreme events and responses to natural hazards. 
* Infrastructure: Built environment, including land use planning, housing, utilities, and public works. Excludes coastal infrastructure and transportation. 
* Health: Includes public health agencies, clinical services, and medical interventions. 
* Education: Includes primary, secondary, and tertiary school systems. 
* Human services: Includes gender equality, immigration, families, Indigenous groups, social affairs, minority affairs, religious affairs, welfare and social services. 
* Agriculture: Includes irrigation, plant/seed technology. 
* Water: Water for human consumption and recreation, as well as irrigation for crops. 
* Environment: Includes natural resources, public park systems, sustainability, mines, meteorology, geosciences, biodiversity, and conservation. 
* Energy: Includes oil, natural gas, hydropower, and electrical grids. 
* Coast management: Coastal settlements infrastructure. 
* Development: Includes international cooperation, development aid, sustainable development, and rural development. - local development included.
* National Security: Military response to instability/volatility associated with climate change. May include responses to population displacement, disease transmission, Arctic sovereignty, or resource conflict. 
* Forestry: Forest ecosystem health; forest ecosystems used in economic activities. Includes game management and community forests. 
* Fisheries: Marine/riparian ecosystem health; marine/riparian ecosystems used in economic activities. 
* Transportation: Includes road/highway maintenance, public transportation, air traffic, railroad systems, shipping. Insurance Private sector. 
* Tourism: Private sector. Includes recreation. 
* Economy: Costs associated with climate change. Includes finance, employment, labour, trade, treasury, industry, and livelihoods. 
* Culture: Impacts of climate change on particular sites or practices considered important to group identity and/or survival. 
* Technology: Includes science, research, and innovation. 
* Inter-sectoral: Multiple sections. 
* Other
Even if you have decided this document is not relevant, please supply a classification.

### Policy Instrument Classification:
After you have decided the sector class of each document, classify it according to the following policy instruments.
* Regulation: Laws defining responsibilities, conferring decision-making authority, defining liabilities, enabling other instruments.
* Inter-governmental mandate: Directives requiring adaptation by other levels of government.
* Spatial planning: Rules for allocating land uses, public space design standards (including tree planting).
* Infrastructure performance standards:  Standards for infrastructure performance, including performance assessment requirement (e.g. flood risk assessment).
* Building regulations: Rules for building and construction standards. 
* Strategic planning: Adoption of policy guidance documents that integrate adaptation considerations in impacted sectors (including sustainability planning). 
* Adaptation planning: Adoption of policy guidance documents for adaptation (including climate or resilience plans that cover adaptation).
* User charges: Fees paid on the basis of service usage.
* Grants or subsidies: Financial transfers awarded on a conditional basis.
* Loans: Financial transfers given on the basis of repayment.
* Direct expenditures: Capital investments (e.g. road works, parks, tree planting); land acquisition. 
* Demostration projects: Use of government- owned facilities to demonstrate new ideas or technologies.
* Operations: Procurement; (emergency) response procedures; procedures for updating policies and protocols; routine maintenance; best practices implementation.
* Facilities: Adapting city facilities to different purposes (e.g. cooling centers); upgrading city- owned properties.
Even if you have decided this document is not relevant, please supply a classification.
""".strip()

prompt = """
# Research task
You are a helpful AI assistant trained by Meta AI that is uniquely skilled at helping people with data collection and other associated research tasks.
You will be given the text from a webpage or PDF, its title, if one exists, and its url. From this information you must decide how relevant this webpage to the research goal.
The cateogries of relevancy should only be one of the following: 'Not relevant', 'Somewhat relevant', 'Relevant', 'Very relevant', 'Highly relevant'.
No matter the input, you should respond with two things 1) a determination of whether or not this input is relevant to the research goal and 2) a short comment on why you made that determination.

## Research Goal
{research_goal}

## Input website
### Title
{title}
### URL
{url}
### Text
{text}

## Correctly formatted relevancy determination
""".strip()

json_schema = {
    "type": "object",
    "properties": {
        "relevancy": {"type": "string"},
        "comment": {"type": "string"},
        "hazard_class": {"type":"string"},
        "sector_class": {"type":"string"},
        "policy_instrument":{"type":"string"}
    }
}

# %%
llm_surfer = LLMSurfer(
    llm_name = "/cluster/tufts/tuftsai/models/llama-3-70B-instruct", 
    research_goal = research_goal, 
    base_prompt = prompt, 
    query = query, 
    max_results = max_results, 
    json_schema = json_schema,
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
rel_docs = llm_surfer(num_rel_chunks=5) # change to get more or less rel chunks in the output
rel_docs
# Out:
# Collecting links from congress
# 100%|██████████| 5/5 [01:30<00:00, 18.15s/it]
# 5 links collected out of 5. The rest are unreachable
# ----------------------------------------------------------------------------------------------------
# Webpage #1
# Reading URL: https://www.congress.gov/118/bills/hr870/BILLS-118hr870ih.xml
# Result 1: Not relevant, A bill to authorize appropriations for the United States Fire Administration and firefighter assistance grant programs, to advance the benefits of nuclear energy, and for other purposes. because: This bill does not mention climate change, adaptation, or any related policies. It appears to be focused on payments made by the Department of Justice to certain companies and has no connection to climate adaptation policies.
# ----------------------------------------------------------------------------------------------------
# Webpage #2
# Reading URL: https://www.congress.gov/118/bills/hr4366/BILLS-118hr4366rh.xml
# Result 2: Not relevant, Consolidated Appropriations Act, 2024 because: This document appears to be a federal appropriations act, which does not directly address climate adaptation policies or hazards.
# ----------------------------------------------------------------------------------------------------
# Webpage #3
# Reading URL: https://www.congress.gov/118/bills/hr3935/BILLS-118hr3935ih.xml
# Result 3: Somewhat relevant, FAA Reauthorization Act of 2024 because: This policy is somewhat relevant as it deals with the use of unmanned aircraft systems for wildfire detection, mitigation, and suppression, which is related to climate-related hazards. However, it does not directly address climate adaptation or resilience.
# ----------------------------------------------------------------------------------------------------
# Webpage #4
# Reading URL: https://www.congress.gov/118/plaws/publ31/PLAW-118publ31_uslm.xml
# Result 4: Not relevant, National Defense Authorization Act for Fiscal Year 2024 because: The text primarily focuses on defense-related policies and operations, with no explicit mention of climate adaptation or hazard mitigation. The exceptions and limitations mentioned are related to procurement and operations for wildfire management, search and rescue, and intelligence activities, which are not directly related to climate adaptation.
# ----------------------------------------------------------------------------------------------------
# Webpage #5
# Reading URL: https://www.congress.gov/118/plaws/publ15/PLAW-118publ15_uslm.xml
# Result 5: Somewhat relevant, Continuing Appropriations Act, 2024 and Other Extensions Act because: The text mentions Wildland Fire Management and funding for firefighter base salary increases, which may be related to climate adaptation policies, but it does not explicitly mention climate change or adaptation.
# ----------------------------------------------------------------------------------------------------
#                                                title  \
# 0  A bill to authorize appropriations for the Uni...
# 1              Consolidated Appropriations Act, 2024
# 2                    FAA Reauthorization Act of 2024
# 3  National Defense Authorization Act for Fiscal ...
# 4  Continuing Appropriations Act, 2024 and Other ...
#
#                                                  url          relevancy  \
# 0  https://www.congress.gov/118/bills/hr870/BILLS...       Not relevant
# 1  https://www.congress.gov/118/bills/hr4366/BILL...       Not relevant
# 2  https://www.congress.gov/118/bills/hr3935/BILL...  Somewhat relevant
# 3  https://www.congress.gov/118/plaws/publ31/PLAW...       Not relevant
# 4  https://www.congress.gov/118/plaws/publ15/PLAW...  Somewhat relevant
#
#                                          llm_comment  year  \
# 0  This bill does not mention climate change, ada...  2023
# 1  This document appears to be a federal appropri...  2023
# 2  This policy is somewhat relevant as it deals w...  2023
# 3  The text primarily focuses on defense-related ...  2023
# 4  The text mentions Wildland Fire Management and...  2023
#
#                                    alternative_title     hazard_class  \
# 0  118 HR 870 IH: Exposing Lewd Outlays for socia...   Not applicable
# 1  118 HR 4366 RH: Military Construction, Veteran...   Not applicable
# 2  108 HR 3935 IH: Securing Growth and Robust Lea...  Explicit Hazard
# 3  Public Law 118–31: To authorize appropriations...   Not applicable
# 4  Public Law 118–15: Making continuing appropria...         Implicit
#
#            sector_class    policy_instrument  \
# 0        Not applicable       Not applicable
# 1        Not applicable       Not applicable
# 2  Emergency management           Regulation
# 3     National Security           Regulation
# 4  Emergency management  Grants or subsidies
#
#                                Most Relevant Chunk 1  \
# 0  IVESFebruary 8, 2023Mrs. Boebert (for herself,...
# 1  The Federal Government shall consider accredit...
# 2   areas of public land with high potential for ...
# 3  iral.”.(B) Subsection (b) is amended—(i) in pa...
# 4   made available by section 101 for “Department...
#
#                                Most Relevant Chunk 2  \
# 0  \n\n118 HR 870 IH: Exposing Lewd Outlays for s...
# 1  1) of title 5, United States Code; and(B)the t...
# 2   systems in wildfire response(1)In generalNot ...
# 3  ”; and(iii) in subparagraph (C), by striking “...
# 4   with respect to such period, for fiscal year ...
#
#                                Most Relevant Chunk 3  \
# 0   to any of the following companies:(1)Twitter....
# 1  .(b)(1)None of the funds made available by thi...
# 2  d)Savings clauseNothing in this Act shall be c...
# 3   (3)—(I) in subparagraph (A), by striking “or ...
# 4   “or period” after “the fiscal year”;(B) in pa...
#
#                                Most Relevant Chunk 4  \
# 0   committees definedIn this section, the term r...
# 1   under the laws providing such benefits to vet...
# 2   local government;(D)a Tribal government; and(...
# 3  F) The Committee on Homeland Security of the H...
# 4   Fire Management” in title VII of division N o...
#
#                                Most Relevant Chunk 5
# 0   Act may be cited as the Exposing Lewd Outlays...
# 1   headquarters is selected other than the prefe...
# 2  .(4)PublicationUpon submission of the plan und...
# 3  aint or Request Defined.—In this section, the ...
# 4   117–328, and title III of division O of Publi...

# %% [markdown]
# # OpenAlex

# %%
from llm_surfer import LLMSurfer

# %%
query = """
extreme heat action plan
""".strip()

max_results = 5

research_goal = """
The purpose of this project is to study what governments (local, state, and national) are doing to prepare for extreme heat events. In many places across the world, extreme heat is a growing public health threat. We’re interested in studying extreme heat policies anywhere that they have been enacted. The goal of this phase of research is to compile an inventory of academic articles that analyze the functionality of extreme heat policies. We will use this to evaluate the effectiveness of different extreme heat policies in practice. By policy in practice, we mean public policies that have been implemented and studied, not just suggested, or modelled. 

### Inclusion requirements: 
* Is a peer-reviewed article
* Article studies a policy type from our list (or search string) and relates to extreme heat
* Article studies already implemented policies 
* Article analyzes the functionality of said policy or policies. Functionality can be defined broadly as how well the policy works. 
* This could include (a non-exhaustive list): 
    - associated costs
    - equity impacts: how does the policy impact different groups of people?
    - impact on heat related mortality and morbidity
    - durability 
    - functionality: does it achieve its stated aims?
    
### Exclusion requirements: 
* Article constitutes a literature review
* Article models the potential effects of policies or studies aspirational policies
* Article studies extreme heat measures that do not constitute policies
    - For example, an article that studies the functionality of ‘cool roofs’ is not sufficient unless it is analyzing a mechanism, such as a tax rebate, that helps to institute cool roofs.
""".strip()

prompt = """
# Research task
You are a helpful AI assistant trained by Meta AI that is uniquely skilled at helping people with data collection and other associated research tasks.
You will be given the text from a webpage or PDF, its title, if one exists, and its url. From this information you must decide whether or not it is relevant to a specific research goal, outlined below.
No matter the input, you should respond with two things 1) a determination of whether or not this input is relevant to the research goal and 2) a short comment on why you made that determination.

## Research Goal
{research_goal}

## Input website
### Title
{title}
### URL
{url}
### Text
{text}

## Correctly formatted relevancy determination
"""

json_schema = {
    "type": "object",
    "properties": {
        "relevancy": {"type": "boolean"},
        "comment": {"type": "string"}
    }
}

# %%
llm_surfer = LLMSurfer(
    llm_name = "/cluster/tufts/tuftsai/models/llama-3-8B-instruct", 
    search_engine = 'openalex',
    research_goal = research_goal, 
    base_prompt = prompt, 
    query = query, 
    max_results = max_results, 
    json_schema = json_schema,
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
rel_docs = llm_surfer()
rel_docs
# Out:
# Collecting links from openalex
# Retrieving results from OpenAlex
# Reading OpenAlex Page 5
#  40%|████      | 2/5 [00:15<00:23,  7.82s/it]
# No text found. Skipping...
# New result added.
#  80%|████████  | 4/5 [00:32<00:08,  8.17s/it]
# No text found. Skipping...
# New result added.
# 100%|██████████| 5/5 [00:40<00:00,  7.92s/it]
# No text found. Skipping...
# New result added.
# 7it [00:56,  8.07s/it]
# No text found. Skipping...
# New result added.
# 8it [01:04,  7.91s/it]
# No text found. Skipping...
# New result added.
# 10it [01:24,  8.42s/it]
# 5 links collected out of 5. The rest are unreachable
# ----------------------------------------------------------------------------------------------------
# Webpage #1
# Reading URL: https://doi.org/10.1007/s00484-022-02326-x
# Result 1: True, Evaluations of heat action plans for reducing the health impacts of extreme heat: methodological developments (2012–2021) and remaining challenges because: The article is relevant to the research goal as it evaluates heat action plans for reducing the health impacts of extreme heat, and it focuses on already implemented policies. The article meets the inclusion requirements of being a peer-reviewed article, studying implemented policies, and analyzing their functionality. The article's methodology and findings on the evaluations of heat action plans align with the research goal's focus on the effectiveness of extreme heat policies in practice.
# ----------------------------------------------------------------------------------------------------
# Webpage #2
# Reading URL: https://doi.org/10.1146/annurev-publhealth-012420-105026
# Result 2: False, Extreme Weather and Climate Change: Population Health and Health System Implications because: This article discusses the impact of extreme weather events, such as heat waves, cyclones, and floods, on human health, but it does not analyze the functionality of specific policies that have been implemented to address extreme heat events. The article is more focused on the broader topics of climate variability and its effects on health, rather than examining the implementation and effectiveness of specific policies. As a result, it does not meet the inclusion requirements specified for this research goal.
# ----------------------------------------------------------------------------------------------------
# Webpage #3
# Reading URL: https://doi.org/10.3390/ijerph16152657
# Result 3: False, Overview of Existing Heat-Health Warning Systems in Europe because: The article 'Overview of Existing Heat-Health Warning Systems in Europe' seems to be a literature review or a summary of existing heat-health warning systems in Europe, rather than a study that analyzes the functionality of implemented policies. The article does not appear to focus on the specific functionality of a heat policy, but rather provides an overview of the current state of heat-health warning systems in Europe. As per the exclusion requirements, this article does not meet the criteria for inclusion in the research goal.
# ----------------------------------------------------------------------------------------------------
# Webpage #4
# Reading URL: https://doi.org/10.3402/ijch.v68i1.18293
# Result 4: False, Prevention and management of health hazards related to heatwaves because: The provided article title, 'Prevention and management of health hazards related to heatwaves', suggests that it may be relevant to extreme heat events. However, upon reviewing the text, it appears that the article is primarily a metadata summary of a published article, including information such as the number of CrossRef citations and Altmetric views. There is no actual content or analysis in the provided text. Therefore, it does not meet the research goal criteria as it does not study an implemented policy related to extreme heat and its functionality.
# ----------------------------------------------------------------------------------------------------
# Webpage #5
# Reading URL: https://doi.org/10.1073/pnas.1806393116
# Result 5: False, Assessment of extreme heat and hospitalizations to inform early warning systems because: This article does not seem to be relevant to the research goal as it appears to be a scientific study on the genetic changes in a species of lizard, discussing the genetic mechanisms underlying the color morphs of the lizards. The study does not mention heat events, policies, or the functionality of any policy related to heat. The research goal is focused on analyzing the functionality of extreme heat policies, which is not the focus of this article.
# ----------------------------------------------------------------------------------------------------
#                                                title  \
# 0  Evaluations of heat action plans for reducing ...
# 1  Extreme Weather and Climate Change: Population...
# 2  Overview of Existing Heat-Health Warning Syste...
# 3  Prevention and management of health hazards re...
# 4  Assessment of extreme heat and hospitalization...
#
#                                                  url  relevancy  \
# 0         https://doi.org/10.1007/s00484-022-02326-x       True
# 1  https://doi.org/10.1146/annurev-publhealth-012...      False
# 2             https://doi.org/10.3390/ijerph16152657      False
# 3           https://doi.org/10.3402/ijch.v68i1.18293      False
# 4            https://doi.org/10.1073/pnas.1806393116      False
#
#                                          llm_comment  \
# 0  The article is relevant to the research goal a...
# 1  This article discusses the impact of extreme w...
# 2  The article 'Overview of Existing Heat-Health ...
# 3  The provided article title, 'Prevention and ma...
# 4  This article does not seem to be relevant to t...
#
#                                Most Relevant Chunk 1  \
# 0   following search terms were used for the publ...
# 1   more resilient infrastructure. The risks are ...
# 2  ito, M.;                     Flouris, A.D.;   ...
# 3                 CrossRef citations to date     ...
# 4  10.1073/pnas.1806393116 Copied! Copying failed...
#
#                                Most Relevant Chunk 2  \
# 0  * OR validat* OR effective* or efficacy OR rev...
# 1   to Earth's energy balance are increasing the ...
# 2                                Schwierz C.     ...
# 3                      2,658                     ...
# 4      Enter your email address below and we will...
#
#                                Most Relevant Chunk 3  \
# 0  J., Barry, S.J.E., Megiddo, I. et al. Evaluati...
# 1  We use cookies to track usage and preferences....
# 2             Spirig, C.;                     Sch...
# 3                                                NaN
# 4   has been cited by providing the context of th...
#
#                                Most Relevant Chunk 4  \
# 0  - https://www.toronto.ca/ Canada - (national) ...
# 1                                                NaN
# 2  .                        Overview of Existing ...
# 3                                                NaN
# 4  izards' color morphs. The findings suggest tha...
#
#                                Most Relevant Chunk 5
# 0   Article                         Google Schola...
# 1                                                NaN
# 2     Schwierz, C.            Overview of Existin...
# 3                                                NaN
# 4  Get alerts for new articles, or get an alert w...
